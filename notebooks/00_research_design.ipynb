# %%
import sys

print(sys.executable)
print("Notebook kernel is working")
# Out:
# c:\Users\user\miniconda3\envs\paper_env\python.exe
# Notebook kernel is working

# %% [markdown]
# # Quantitative Paper Replication
#
# **Author:** Adam Al debes
# **Purpose:** Reproduce, validate, and extend the results of a published quantitative research paper.
